# %% [markdown]
# ![image.png](attachment:7b671365-9765-4306-aa7b-7f539d191cc8.png)

# %% [markdown]
# ![image.png](attachment:0e7365fc-142c-4d02-9757-470661ff9488.png)

# %% [markdown]
# ![image.png](attachment:5435df58-a33b-472a-89c0-7211a7eb23f2.png)

# %% [markdown]
# ![image.png](attachment:a7cc541e-2f53-401f-9867-bfa4a6c2dabe.png)

# %% [markdown]
# ![image.png](attachment:bdca9e0a-0807-42ed-a675-fad892d84ee7.png)

# %% [markdown]
# ![image.png](attachment:b5d67f9e-fd2d-4c63-b892-949f603ec62f.png)

# %% [markdown]
# ![image.png](attachment:7f743bdf-8148-44e1-8ed1-e8c74253871a.png)

# %% [markdown]
# ![image.png](attachment:3754e195-1288-4b09-802a-1f752feebbdc.png)

# %% [markdown]
# ![image.png](attachment:b21ed9c5-0bc7-4d92-b27e-ed31028c05b0.png)

# %% [markdown]
# ![image.png](attachment:c72c27b3-6166-443f-ae4b-6c8fa71f6ae5.png)
