# %% [markdown]
# ---
# # 통계세미나 발표

# %% [markdown]
# ![image.png](attachment:72764a1d-a51e-4947-bab1-e1fe9b78ef12.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:6e035662-ff54-4fb8-93f4-88e9a0f54be9.png)

# %% [markdown]
# ![image.png](attachment:e994be61-a9d8-44de-8cb0-48af351b223f.png)

# %% [markdown]
# ![image.png](attachment:b96c14c3-0136-4637-beca-086461d584c3.png)

# %% [markdown]
# ![image.png](attachment:3bda436b-6771-4b4e-b5d2-1fcfeaf5f8fe.png)

# %% [markdown]
# ![image.png](attachment:03302e00-fe4e-4d9c-8aaa-9159981cd1b3.png)

# %% [markdown]
# ![image.png](attachment:e648ecde-fb8e-41fa-96f0-f69a66158737.png)

# %% [markdown]
# ![image.png](attachment:c96b9594-9a6e-4605-b30b-b82bba017d8f.png)

# %% [markdown]
# ![image.png](attachment:c71d834a-8062-41a6-9449-6e85918caaf1.png)

# %% [markdown]
# ![image.png](attachment:d1492345-21bd-48cf-8544-ba7f7ef77950.png)

# %% [markdown]
# ![image.png](attachment:4feecc62-30b8-48af-9579-6bc1fd5ede66.png)

# %% [markdown]
# ![image.png](attachment:584d3c51-ddd3-48e7-9d9e-614b0dae82f9.png)

# %% [markdown]
# ![image.png](attachment:a262c27a-be52-4b05-9b37-90d640b40c5a.png)

# %% [markdown]
# ![image.png](attachment:cdd6afc5-2dea-42bb-b329-ce18a116002d.png)

# %% [markdown]
# ![image.png](attachment:62edd694-0612-4c5d-b177-7ca34e042edf.png)

# %% [markdown]
# ![image.png](attachment:0894c32d-d548-4726-bd61-b999fc7193af.png)
